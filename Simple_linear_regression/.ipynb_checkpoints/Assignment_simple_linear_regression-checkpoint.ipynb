# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
X = df.drop('Salary',axis=1)
y = df['Salary']

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.scatterplot(x='YearsExperience',y='Salary',data=df)
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression(normalize=False)

# %%
lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 69088.8

# %%
lr.coef_
# Out:
# array([22993.14534978])

# %%
lr.score(X_train_scaled,y_train)
# Out:
# 0.9300257612268853

# %%
lr.score(X_test_scaled,y_test)
# Out:
# 0.974811112371526

# %% [markdown]
# ### Person with 20 years of experience salary

# %%
value = scaler.transform([[20]])

# %%
value
# Out:
# array([[6.53790509]])

# %%
print(np.round(lr.predict(value),2))
# Out:
# [219415.8]

# %%
import statsmodels.api as sm
X1 = sm.add_constant(X_train_scaled)
result = sm.OLS(y_train, X1).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Salary   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     239.2
# Date:                Thu, 20 May 2021   Prob (F-statistic):           7.71e-12
# Time:                        16:08:21   Log-Likelihood:                -203.37
# No. Observations:                  20   AIC:                             410.7
# Df Residuals:                      18   BIC:                             412.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.909e+04   1486.564     46.475      0.000     6.6e+04    7.22e+04
# x1          2.299e+04   1486.564     15.467      0.000    1.99e+04    2.61e+04
# ==============================================================================
# Omnibus:                        6.959   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                1.782
# Skew:                           0.085   Prob(JB):                        0.410
# Kurtosis:                       1.548   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Delivery Time

# %%
df = pd.read_csv("delivery_time.csv")

# %%
df.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
df.dtypes
# Out:
# Delivery Time    float64
# Sorting Time       int64
# dtype: object

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
sns.scatterplot(x='Sorting Time',y='Delivery Time',data=df)
# Out:
# <AxesSubplot:xlabel='Sorting Time', ylabel='Delivery Time'>

# %%
df.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
X = df.drop('Delivery Time',axis=1)
y = df['Delivery Time']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
scale = StandardScaler()

# %%
x_scaled_train = scale.fit_transform(X_train)
x_scaled_test = scale.transform(X_test)

# %%
regressor = LinearRegression(normalize=False)

# %%
regressor.fit(x_scaled_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# 17.591428571428573

# %%
regressor.score(x_scaled_train,y_train)
# Out:
# 0.5716056144912427

# %%
regressor.coef_
# Out:
# array([3.46345467])

# %%
X1 = sm.add_constant(x_scaled_train)
result = sm.OLS(y_train, X1).fit()

# %%
result.summary()
# Out:
# C:\Users\Chinmay\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=14
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Delivery Time   R-squared:                       0.572
# Model:                            OLS   Adj. R-squared:                  0.536
# Method:                 Least Squares   F-statistic:                     16.01
# Date:                Thu, 20 May 2021   Prob (F-statistic):            0.00176
# Time:                        16:11:51   Log-Likelihood:                -35.238
# No. Observations:                  14   AIC:                             74.48
# Df Residuals:                      12   BIC:                             75.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.5914      0.866     20.324      0.000      15.706      19.477
# x1             3.4635      0.866      4.001      0.002       1.578       5.349
# ==============================================================================
# Omnibus:                        5.552   Durbin-Watson:                   2.144
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                2.892
# Skew:                           1.080   Prob(JB):                        0.236
# Kurtosis:                       3.542   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
