# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Company_Data.csv')

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
df.tail()
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes

# %%
df = pd.get_dummies(df)

# %%
df.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good',
#        'ShelveLoc_Medium', 'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes'],
#       dtype='object')

# %%
df.corr()
# Out:
#                      Sales  CompPrice    Income  Advertising  Population  \
# Sales             1.000000   0.064079  0.151951     0.269507    0.050471
# CompPrice         0.064079   1.000000 -0.080653    -0.024199   -0.094707
# Income            0.151951  -0.080653  1.000000     0.058995   -0.007877
# Advertising       0.269507  -0.024199  0.058995     1.000000    0.265652
# Population        0.050471  -0.094707 -0.007877     0.265652    1.000000
# Price            -0.444951   0.584848 -0.056698     0.044537   -0.012144
# Age              -0.231815  -0.100239 -0.004670    -0.004557   -0.042663
# Education        -0.051955   0.025197 -0.056855    -0.033594   -0.106378
# ShelveLoc_Bad    -0.393167  -0.035393  0.072017    -0.035217    0.039902
# ShelveLoc_Good    0.500510   0.026386 -0.012657     0.056149    0.007789
# ShelveLoc_Medium -0.073999   0.008683 -0.051392    -0.015929   -0.040640
# Urban_No          0.015419  -0.066594 -0.037967    -0.042035    0.052025
# Urban_Yes        -0.015419   0.066594  0.037967     0.042035   -0.052025
# US_No            -0.177093  -0.016869 -0.089601    -0.684460   -0.060564
# US_Yes            0.177093   0.016869  0.089601     0.684460    0.060564
#
#                      Price       Age  Education  ShelveLoc_Bad  \
# Sales            -0.444951 -0.231815  -0.051955      -0.393167
# CompPrice         0.584848 -0.100239   0.025197      -0.035393
# Income           -0.056698 -0.004670  -0.056855       0.072017
# Advertising       0.044537 -0.004557  -0.033594      -0.035217
# Population       -0.012144 -0.042663  -0.106378       0.039902
# Price             1.000000 -0.102177   0.011747      -0.036220
# Age              -0.102177  1.000000   0.006488      -0.044123
# Education         0.011747  0.006488   1.000000       0.012525
# ShelveLoc_Bad    -0.036220 -0.044123   0.012525       1.000000
# ShelveLoc_Good    0.045854 -0.022818  -0.029188      -0.291913
# ShelveLoc_Medium -0.006607  0.056613   0.013242      -0.618133
# Urban_No         -0.047016 -0.028479   0.033094      -0.081122
# Urban_Yes         0.047016  0.028479  -0.033094       0.081122
# US_No            -0.057861 -0.008652   0.078250      -0.000979
# US_Yes            0.057861  0.008652  -0.078250       0.000979
#
#                   ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# Sales                   0.500510         -0.073999  0.015419  -0.015419
# CompPrice               0.026386          0.008683 -0.066594   0.066594
# Income                 -0.012657         -0.051392 -0.037967   0.037967
# Advertising             0.056149         -0.015929 -0.042035   0.042035
# Population              0.007789         -0.040640  0.052025  -0.052025
# Price                   0.045854         -0.006607 -0.047016   0.047016
# Age                    -0.022818          0.056613 -0.028479   0.028479
# Education              -0.029188          0.013242  0.033094  -0.033094
# ShelveLoc_Bad          -0.291913         -0.618133 -0.081122   0.081122
# ShelveLoc_Good          1.000000         -0.571396  0.039197  -0.039197
# ShelveLoc_Medium       -0.571396          1.000000  0.037391  -0.037391
# Urban_No                0.039197          0.037391  1.000000  -1.000000
# Urban_Yes              -0.039197         -0.037391 -1.000000   1.000000
# US_No                  -0.078864          0.065656  0.047085  -0.047085
# US_Yes                  0.078864         -0.065656 -0.047085   0.047085
#
#                      US_No    US_Yes
# Sales            -0.177093  0.177093
# CompPrice        -0.016869  0.016869
# Income           -0.089601  0.089601
# Advertising      -0.684460  0.684460
# Population       -0.060564  0.060564
# Price            -0.057861  0.057861
# Age              -0.008652  0.008652
# Education         0.078250 -0.078250
# ShelveLoc_Bad    -0.000979  0.000979
# ShelveLoc_Good   -0.078864  0.078864
# ShelveLoc_Medium  0.065656 -0.065656
# Urban_No          0.047085 -0.047085
# Urban_Yes        -0.047085  0.047085
# US_No             1.000000 -1.000000
# US_Yes           -1.000000  1.000000

# %%
df.drop(['US_No','ShelveLoc_Medium','Urban_No','Urban_Yes','Education','Population'],inplace=True,axis=1)

# %%
X = df.drop('Sales',axis=1)
y = df['Sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled_train = scaler.fit_transform(X_train)

X_scaled_test = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree_reg = DecisionTreeRegressor()
dtree_reg.fit(X_scaled_train,y_train)
print(dtree_reg.feature_importances_)
# Out:
# [0.12189815 0.06176542 0.09443533 0.3209185  0.06958612 0.04374638
#  0.26246436 0.02518573]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV, KFold , RandomizedSearchCV

# %%
rfr = RandomForestRegressor()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
min_samples_split = [3,4,5,6,7,8]
max_depth = [3,4,5,6,7]
max_features = [None,3,4,5]
n_estimators = [90,100,125,150,200]
n_jobs =[-1]

param_grid = dict(n_estimators = n_estimators, n_jobs = n_jobs, min_samples_split = min_samples_split,max_depth = max_depth,max_features= max_features,)

grid = GridSearchCV(estimator = rfr,param_grid = param_grid,cv = KFold(n_splits=5,shuffle=True), verbose = 10)
grid_result = grid.fit(X_scaled_train,y_train)
# Out:
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [CV 1/5; 1/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 1/5; 1/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   5.3s
# [CV 2/5; 1/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 2/5; 1/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 1/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 3/5; 1/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 1/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 4/5; 1/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 1/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 5/5; 1/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 2/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 1/5; 2/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 2/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 2/5; 2/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 2/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 3/5; 2/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.3s
# [CV 4/5; 2/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 4/5; 2/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 5/5; 2/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 5/5; 2/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 1/5; 3/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 1/5; 3/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 3/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 2/5; 3/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 3/5; 3/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 3/5; 3/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 4/5; 3/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 4/5; 3/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 3/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 5/5; 3/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 4/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 1/5; 4/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 4/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 2/5; 4/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 4/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 3/5; 4/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 4/5; 4/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 4/5; 4/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 5/5; 4/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 5/5; 4/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 5/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 1/5; 5/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 5/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 2/5; 5/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 3/5; 5/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 3/5; 5/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 5/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 4/5; 5/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.4s
# [CV 5/5; 5/600] START max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 5/5; 5/600] END max_depth=3, max_features=None, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 6/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 1/5; 6/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 6/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 2/5; 6/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 6/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 3/5; 6/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 4/5; 6/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 4/5; 6/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 5/5; 6/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 5/5; 6/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 7/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 1/5; 7/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 7/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 2/5; 7/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 7/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 3/5; 7/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 7/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 4/5; 7/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 7/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 5/5; 7/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 8/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 1/5; 8/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 8/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 2/5; 8/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 8/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 3/5; 8/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 8/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 4/5; 8/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 5/5; 8/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 5/5; 8/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 9/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 1/5; 9/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 2/5; 9/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 2/5; 9/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 9/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 3/5; 9/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 9/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 4/5; 9/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 9/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 5/5; 9/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 10/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 1/5; 10/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 2/5; 10/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 2/5; 10/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 3/5; 10/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 3/5; 10/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 10/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 4/5; 10/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 10/600] START max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 5/5; 10/600] END max_depth=3, max_features=None, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 1/5; 11/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 1/5; 11/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 11/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 2/5; 11/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 11/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 3/5; 11/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 11/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 4/5; 11/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 11/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 5/5; 11/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 12/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/5; 12/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 12/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/5; 12/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 12/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 3/5; 12/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 12/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 4/5; 12/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 12/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 5/5; 12/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 13/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 1/5; 13/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 13/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 2/5; 13/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 13/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 3/5; 13/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 13/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 4/5; 13/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 13/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 5/5; 13/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 14/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV 1/5; 14/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 14/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV 2/5; 14/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 14/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV 3/5; 14/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 14/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV 4/5; 14/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 14/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1
# [CV 5/5; 14/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 15/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV 1/5; 15/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 2/5; 15/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV 2/5; 15/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1; total time=   0.4s
# [CV 3/5; 15/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV 3/5; 15/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 4/5; 15/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV 4/5; 15/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 5/5; 15/600] START max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1
# [CV 5/5; 15/600] END max_depth=3, max_features=None, min_samples_split=5, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 16/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 1/5; 16/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 2/5; 16/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 2/5; 16/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 16/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 3/5; 16/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 16/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 4/5; 16/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 16/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 5/5; 16/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 17/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 1/5; 17/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 17/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 2/5; 17/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 17/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 3/5; 17/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 17/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 4/5; 17/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 17/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 5/5; 17/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 18/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 1/5; 18/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 18/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 2/5; 18/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 18/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 3/5; 18/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 4/5; 18/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 4/5; 18/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 18/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 5/5; 18/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 1/5; 19/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 1/5; 19/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 19/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 2/5; 19/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 19/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 3/5; 19/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 19/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 4/5; 19/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 19/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 5/5; 19/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 20/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 1/5; 20/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 20/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 2/5; 20/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 3/5; 20/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 3/5; 20/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 4/5; 20/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 4/5; 20/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 20/600] START max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 5/5; 20/600] END max_depth=3, max_features=None, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 21/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 1/5; 21/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 21/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 2/5; 21/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 21/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 3/5; 21/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 21/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 4/5; 21/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 21/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 5/5; 21/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 22/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 1/5; 22/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 22/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 2/5; 22/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 22/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 3/5; 22/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 4/5; 22/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 4/5; 22/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 5/5; 22/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 5/5; 22/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 23/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 1/5; 23/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 23/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 2/5; 23/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 23/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 3/5; 23/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 4/5; 23/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 4/5; 23/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 5/5; 23/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 5/5; 23/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 1/5; 24/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 1/5; 24/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 2/5; 24/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 2/5; 24/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.4s
# [CV 3/5; 24/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 3/5; 24/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 4/5; 24/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 4/5; 24/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 5/5; 24/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 5/5; 24/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 1/5; 25/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 1/5; 25/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 2/5; 25/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 2/5; 25/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 3/5; 25/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 3/5; 25/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.4s
# [CV 4/5; 25/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 4/5; 25/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.4s
# [CV 5/5; 25/600] START max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 5/5; 25/600] END max_depth=3, max_features=None, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.4s
# [CV 1/5; 26/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 1/5; 26/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 2/5; 26/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 2/5; 26/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 26/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 3/5; 26/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 26/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 4/5; 26/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 5/5; 26/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 5/5; 26/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.2s
# [CV 1/5; 27/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 1/5; 27/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 2/5; 27/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 2/5; 27/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 27/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 3/5; 27/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 4/5; 27/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 4/5; 27/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 5/5; 27/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 5/5; 27/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.2s
# [CV 1/5; 28/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 1/5; 28/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 28/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 2/5; 28/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.3s
# [CV 3/5; 28/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 3/5; 28/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 4/5; 28/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 4/5; 28/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 5/5; 28/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 5/5; 28/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 1/5; 29/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 1/5; 29/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 29/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 2/5; 29/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 29/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 3/5; 29/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 29/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 4/5; 29/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 5/5; 29/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 5/5; 29/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.3s
# [CV 1/5; 30/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 1/5; 30/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 2/5; 30/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 2/5; 30/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 3/5; 30/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 3/5; 30/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 30/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 4/5; 30/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 30/600] START max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 5/5; 30/600] END max_depth=3, max_features=None, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 31/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 1/5; 31/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 31/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 2/5; 31/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 31/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 3/5; 31/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 31/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 4/5; 31/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 31/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1
# [CV 5/5; 31/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 32/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 1/5; 32/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 32/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 2/5; 32/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 32/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 3/5; 32/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 32/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 4/5; 32/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 32/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1
# [CV 5/5; 32/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 33/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 1/5; 33/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 33/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 2/5; 33/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 33/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 3/5; 33/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 4/5; 33/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 4/5; 33/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 33/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1
# [CV 5/5; 33/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 34/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 1/5; 34/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 34/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 2/5; 34/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 34/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 3/5; 34/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 34/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 4/5; 34/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 34/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1
# [CV 5/5; 34/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 35/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 1/5; 35/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 35/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 2/5; 35/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 3/5; 35/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 3/5; 35/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 35/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 4/5; 35/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 35/600] START max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1
# [CV 5/5; 35/600] END max_depth=3, max_features=3, min_samples_split=3, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 36/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 1/5; 36/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 36/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 2/5; 36/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 36/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 3/5; 36/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 36/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 4/5; 36/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 36/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1
# [CV 5/5; 36/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 37/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 1/5; 37/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 37/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 2/5; 37/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 37/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 3/5; 37/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 37/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 4/5; 37/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 37/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1
# [CV 5/5; 37/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 38/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 1/5; 38/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 2/5; 38/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 2/5; 38/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 38/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 3/5; 38/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 38/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 4/5; 38/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 38/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1
# [CV 5/5; 38/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 39/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 1/5; 39/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 39/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 2/5; 39/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 39/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 3/5; 39/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 39/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 4/5; 39/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 39/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1
# [CV 5/5; 39/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 40/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 1/5; 40/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 2/5; 40/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 2/5; 40/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 3/5; 40/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 3/5; 40/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 4/5; 40/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 4/5; 40/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 5/5; 40/600] START max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1
# [CV 5/5; 40/600] END max_depth=3, max_features=3, min_samples_split=4, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 1/5; 41/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 1/5; 41/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 41/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 2/5; 41/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 41/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 3/5; 41/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 41/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 4/5; 41/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 41/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1
# [CV 5/5; 41/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 42/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 1/5; 42/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 42/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 2/5; 42/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 42/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 3/5; 42/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 42/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 4/5; 42/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 42/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1
# [CV 5/5; 42/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 43/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 1/5; 43/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 2/5; 43/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 2/5; 43/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 3/5; 43/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 3/5; 43/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 43/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1
# [CV 4/5; 43/600] END max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 5/5; 43/600] START max_depth=3, max_features=3, min_samples_split=5, n_estimators=125, n_jobs=-1
# ...
# [CV 4/5; 586/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 4/5; 586/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 586/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1
# [CV 5/5; 586/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 587/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 1/5; 587/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 587/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 2/5; 587/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 587/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 3/5; 587/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 587/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 4/5; 587/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 587/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1
# [CV 5/5; 587/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 588/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 1/5; 588/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 2/5; 588/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 2/5; 588/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.2s
# [CV 3/5; 588/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 3/5; 588/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 588/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 4/5; 588/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 588/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1
# [CV 5/5; 588/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 589/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 1/5; 589/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 589/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 2/5; 589/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 589/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 3/5; 589/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 589/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 4/5; 589/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 589/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1
# [CV 5/5; 589/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 590/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 1/5; 590/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 590/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 2/5; 590/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 3/5; 590/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 3/5; 590/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 590/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 4/5; 590/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 590/600] START max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1
# [CV 5/5; 590/600] END max_depth=7, max_features=5, min_samples_split=6, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 1/5; 591/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 1/5; 591/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 591/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 2/5; 591/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 3/5; 591/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 3/5; 591/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 4/5; 591/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 4/5; 591/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 591/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1
# [CV 5/5; 591/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 592/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 1/5; 592/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 592/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 2/5; 592/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 592/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 3/5; 592/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 592/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 4/5; 592/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 592/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1
# [CV 5/5; 592/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 593/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 1/5; 593/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 2/5; 593/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 2/5; 593/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 3/5; 593/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 3/5; 593/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 593/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 4/5; 593/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 593/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1
# [CV 5/5; 593/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 594/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 1/5; 594/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 594/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 2/5; 594/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 594/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 3/5; 594/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 594/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 4/5; 594/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 594/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1
# [CV 5/5; 594/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 595/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 1/5; 595/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 595/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 2/5; 595/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 3/5; 595/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 3/5; 595/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 4/5; 595/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 4/5; 595/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 595/600] START max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1
# [CV 5/5; 595/600] END max_depth=7, max_features=5, min_samples_split=7, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 1/5; 596/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 1/5; 596/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 2/5; 596/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 2/5; 596/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.0s
# [CV 3/5; 596/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 3/5; 596/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.0s
# [CV 4/5; 596/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 4/5; 596/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 5/5; 596/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1
# [CV 5/5; 596/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=90, n_jobs=-1; total time=   0.1s
# [CV 1/5; 597/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 1/5; 597/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 2/5; 597/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 2/5; 597/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 3/5; 597/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 3/5; 597/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 4/5; 597/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 4/5; 597/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 5/5; 597/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1
# [CV 5/5; 597/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=100, n_jobs=-1; total time=   0.1s
# [CV 1/5; 598/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 1/5; 598/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 2/5; 598/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 2/5; 598/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 3/5; 598/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 3/5; 598/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 4/5; 598/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 4/5; 598/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 5/5; 598/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1
# [CV 5/5; 598/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=125, n_jobs=-1; total time=   0.1s
# [CV 1/5; 599/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 1/5; 599/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 2/5; 599/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 2/5; 599/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 3/5; 599/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 3/5; 599/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 4/5; 599/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 4/5; 599/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 5/5; 599/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1
# [CV 5/5; 599/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=150, n_jobs=-1; total time=   0.2s
# [CV 1/5; 600/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 1/5; 600/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 2/5; 600/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 2/5; 600/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.2s
# [CV 3/5; 600/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 3/5; 600/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 4/5; 600/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 4/5; 600/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.3s
# [CV 5/5; 600/600] START max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1
# [CV 5/5; 600/600] END max_depth=7, max_features=5, min_samples_split=8, n_estimators=200, n_jobs=-1; total time=   0.2s

# %%
grid_result.best_params_
# Out:
# {'max_depth': 7,
#  'max_features': None,
#  'min_samples_split': 3,
#  'n_estimators': 200,
#  'n_jobs': -1}

# %%
rfr = RandomForestRegressor(n_estimators=100,max_depth=7, max_features=5, min_samples_split=3,n_jobs=-1)

# %%
rfr.fit(X_scaled_train,y_train)
# Out:
# RandomForestRegressor(max_depth=7, max_features=5, min_samples_split=3,
#                       n_jobs=-1)

# %%
rfr.score(X_scaled_test,y_test)
# Out:
# 0.689901438071727

# %%
prediction = rfr.predict(X_scaled_test)

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(y_test, prediction, squared=True)

# %%
len(y_test)
# Out:
# 132

# %%
(prediction[1] - y_test.iloc[1])
# Out:
# -1.1657396779759202

# %%
y_test.iloc[1]
# Out:
# 8.67

# %%
def mean_squared_error(predict,actual):
    sum =0
    for i in range(len(predict)):
        sum = sum + (prediction[1] - y_test.iloc[1]) * (prediction[1] - y_test.iloc[1])
        
    return sum/len(predict)

# %%
ssr = mean_squared_error(prediction,y_test)

# %%
print(f"Sum of squared residual: {ssr}")
# Out:
# Sum of squared residual: 1.3589489968074038
